# %% [markdown]
# Notebook used to analyze Change My View (Tan et al. 2016) data. The following hypotheses will be tested:
#     H1: Are arguments which use moral language (as detected using either paradigm) more persuasive than those that do not?
#     H2: Other things being equal, a moralistic argument will be more likely to result in a delta if the argument is presented quickly after the initial post.
#     H3: A positive relationship exists between the (Jaccard) similarity of OP and a responder in their MFT affinities and the persuasiveness of that responder.

# %%
import os
import pickle
import pandas as pd
import numpy as np
from scipy import stats
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %%
os.chdir("/Users/amruch/Documents/Research/~ Projects/Cornell Research/SDL/A1 data/")
data_file = "preproc_data.p"
data = pickle.load(open(data_file,'rb'))

# %% [markdown]
# DATASET DESCRIPTION:

# %%
print("(rows, cols):", data.shape)
print("cell size:", data.size)
print("feature types:", '\n', data.dtypes)
print('\n')
print("Head values' content:", '\n', data.head())
# Out:
# (rows, cols): (1239691, 57)
# cell size: 70662387
# feature types:
#  comment_id                       object
# comment_auth                     object
# comment_depth                     int64
# op_id                            object
# op_content                       object
# op_auth                          object
# delta                             int64
# delta_thread                      int64
# time_diff                       float64
# comment_harm_virtue               int64
# op_harm_virtue                    int64
# comment_harm_virtue_bin           int64
# op_harm_virtue_bin                int64
# comment_MFT_usage                 int64
# comment_harm_vice                 int64
# op_harm_vice                      int64
# comment_harm_vice_bin             int64
# op_harm_vice_bin                  int64
# comment_fairness_virtue           int64
# op_fairness_virtue                int64
# comment_fairness_virtue_bin       int64
# op_fairness_virtue_bin            int64
# comment_fairness_vice             int64
# op_fairness_vice                  int64
# comment_fairness_vice_bin         int64
# op_fairness_vice_bin              int64
# comment_ingroup_virtue            int64
# op_ingroup_virtue                 int64
# comment_ingroup_virtue_bin        int64
# op_ingroup_virtue_bin             int64
# comment_ingroup_vice              int64
# op_ingroup_vice                   int64
# comment_ingroup_vice_bin          int64
# op_ingroup_vice_bin               int64
# comment_authority_virtue          int64
# op_authority_virtue               int64
# comment_authority_virtue_bin      int64
# op_authority_virtue_bin           int64
# comment_authority_vice            int64
# op_authority_vice                 int64
# comment_authority_vice_bin        int64
# op_authority_vice_bin             int64
# comment_purity_virtue             int64
# op_purity_virtue                  int64
# comment_purity_virtue_bin         int64
# op_purity_virtue_bin              int64
# comment_purity_vice               int64
# op_purity_vice                    int64
# comment_purity_vice_bin           int64
# op_purity_vice_bin                int64
# comment_morality_general          int64
# op_morality_general               int64
# comment_morality_general_bin      int64
# op_morality_general_bin           int64
# comment_MFT_usage_bin             int64
# jaccard_sim_split               float64
# jaccard_sim_same                float64
# dtype: object
#
#
# Head values' content:
#    comment_id       comment_auth  comment_depth   op_id  \
# 0    d9ujmbi            Ansuz07              1  5c8xdc
# 1    d9ujw71            Ansuz07              3  5c8xdc
# 2    d9ukuqd  Krieg-The-Psycho1              5  5c8xdc
# 3    d9uk6m0            Ansuz07              5  5c8xdc
# 4    d9ukl5h            Ansuz07              7  5c8xdc
#
#                                           op_content     op_auth  delta  \
# 0  I have to say that I am very disappointed with...  ralpher313      0
# 1  I have to say that I am very disappointed with...  ralpher313      1
# 2  I have to say that I am very disappointed with...  ralpher313      0
# 3  I have to say that I am very disappointed with...  ralpher313      0
# 4  I have to say that I am very disappointed with...  ralpher313      0
#
#    delta_thread  time_diff  comment_harm_virtue        ...         \
# 0             1      442.0                    0        ...
# 1             1      758.0                    0        ...
# 2             1     1845.0                    0        ...
# 3             1     1087.0                    0        ...
# 4             1     1544.0                    0        ...
#
#    op_purity_vice  comment_purity_vice_bin  op_purity_vice_bin  \
# 0               0                        0                   0
# 1               0                        0                   0
# 2               0                        1                   0
# 3               0                        0                   0
# 4               0                        0                   0
#
#    comment_morality_general  op_morality_general  \
# 0                         1                    1
# 1                         0                    1
# 2                         0                    1
# 3                         0                    1
# 4                         0                    1
#
#    comment_morality_general_bin  op_morality_general_bin  \
# 0                             1                        1
# 1                             0                        1
# 2                             0                        1
# 3                             0                        1
# 4                             0                        1
#
#    comment_MFT_usage_bin  jaccard_sim_split  jaccard_sim_same
# 0                      1           0.833333          0.714286
# 1                      0           0.571429          0.333333
# 2                      1           0.571429          0.333333
# 3                      0           0.571429          0.333333
# 4                      1           0.692308          0.500000
#
# [5 rows x 57 columns]

# %% [markdown]
# INITIALIZATIONS: OUTCOME LIST, LOCAL VARIABLE LISTS, DATAFRAME SUBSETS

# %%
outcomes = [] # Initialize outcomes list to store model outcomes

# %%
MFT_domains_bin = ['comment_MFT_usage_bin', 'op_harm_virtue_bin',
                   'op_harm_vice_bin', 'comment_harm_virtue_bin',
                   'comment_harm_vice_bin', 'op_fairness_virtue_bin',
                   'op_fairness_vice_bin', 'comment_fairness_virtue_bin',
                   'comment_fairness_vice_bin', 'op_ingroup_virtue_bin',
                   'op_ingroup_vice_bin', 'comment_ingroup_virtue_bin',
                   'comment_ingroup_vice_bin', 'op_authority_virtue_bin',
                   'op_authority_vice_bin', 'comment_authority_virtue_bin',
                   'comment_authority_vice_bin', 'op_purity_virtue_bin',
                   'op_purity_vice_bin', 'comment_purity_virtue_bin',
                   'comment_purity_vice_bin']

MFT_domains_n = ['comment_MFT_usage', 'op_harm_virtue',
                 'op_harm_vice', 'comment_harm_virtue',
                 'comment_harm_vice', 'op_fairness_virtue',
                 'op_fairness_vice', 'comment_fairness_virtue',
                 'comment_fairness_vice', 'op_ingroup_virtue',
                 'op_ingroup_vice', 'comment_ingroup_virtue',
                 'comment_ingroup_vice', 'op_authority_virtue',
                 'op_authority_vice', 'comment_authority_virtue',
                 'comment_authority_vice', 'op_purity_virtue',
                 'op_purity_vice', 'comment_purity_virtue',
                 'comment_purity_vice']

data['MFT_any_n'] = 0
for d in MFT_domains_n:
    data['MFT_any_n'] += data[d]

data['MFT_any_bin'] = 0
data.loc[data['MFT_any_n'] > 0, 'MFT_any_bin'] = 1

# print(data.MFT_any_bin.head())
# print(data.MFT_any_n.head())

MFT_domains_all = MFT_domains_bin + MFT_domains_n + ['MFT_any_bin', 'MFT_any_n']
# print(MFT_domains_all)

# %%
data_subset_deltas = data.query('delta_thread == 1') # Subset of delta-awarded threads
data_subset_moral = data.query('MFT_any_bin == 1') # Subset of moral threads/posts

# data_subset_deltas.head()
# data_subset_moral.head()

# %% [markdown]
# DATA SUMMARIZATION:

# %%
data.describe()
# Out:
#        comment_depth         delta  delta_thread     time_diff  \
# count   1.239691e+06  1.239691e+06  1.239691e+06  1.239691e+06
# mean    3.900733e+00  8.349661e-03  3.905328e-01  7.810454e+04
# std     2.533883e+00  9.099424e-02  4.878700e-01  5.369938e+05
# min     1.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%     2.000000e+00  0.000000e+00  0.000000e+00  9.462000e+03
# 50%     3.000000e+00  0.000000e+00  0.000000e+00  2.535400e+04
# 75%     5.000000e+00  0.000000e+00  1.000000e+00  5.466750e+04
# max     1.000000e+01  1.000000e+00  1.000000e+00  3.448140e+07
#
#        comment_harm_virtue  op_harm_virtue  comment_harm_virtue_bin  \
# count         1.239691e+06    1.239691e+06             1.239691e+06
# mean          2.440665e-01    7.914150e-01             1.451442e-01
# std           7.934000e-01    1.581287e+00             3.522463e-01
# min           0.000000e+00    0.000000e+00             0.000000e+00
# 25%           0.000000e+00    0.000000e+00             0.000000e+00
# 50%           0.000000e+00    0.000000e+00             0.000000e+00
# 75%           0.000000e+00    1.000000e+00             0.000000e+00
# max           3.300000e+01    4.200000e+01             1.000000e+00
#
#        op_harm_virtue_bin  comment_MFT_usage  comment_harm_vice      ...       \
# count        1.239691e+06       1.239691e+06       1.239691e+06      ...
# mean         3.699454e-01       3.659122e+00       5.250534e-01      ...
# std          4.827898e-01       5.653354e+00       1.429614e+00      ...
# min          0.000000e+00       0.000000e+00       0.000000e+00      ...
# 25%          0.000000e+00       0.000000e+00       0.000000e+00      ...
# 50%          0.000000e+00       2.000000e+00       0.000000e+00      ...
# 75%          1.000000e+00       5.000000e+00       0.000000e+00      ...
# max          1.000000e+00       1.690000e+02       8.300000e+01      ...
#
#        op_purity_vice_bin  comment_morality_general  op_morality_general  \
# count        1.239691e+06              1.239691e+06         1.239691e+06
# mean         5.393981e-01              4.433976e-01         1.415558e+00
# std          4.984456e-01              1.080878e+00         2.268870e+00
# min          0.000000e+00              0.000000e+00         0.000000e+00
# 25%          0.000000e+00              0.000000e+00         0.000000e+00
# 50%          1.000000e+00              0.000000e+00         1.000000e+00
# 75%          1.000000e+00              1.000000e+00         2.000000e+00
# max          1.000000e+00              4.600000e+01         6.300000e+01
#
#        comment_morality_general_bin  op_morality_general_bin  \
# count                  1.239691e+06             1.239691e+06
# mean                   2.500583e-01             5.609019e-01
# std                    4.330465e-01             4.962773e-01
# min                    0.000000e+00             0.000000e+00
# 25%                    0.000000e+00             0.000000e+00
# 50%                    0.000000e+00             1.000000e+00
# 75%                    1.000000e+00             1.000000e+00
# max                    1.000000e+00             1.000000e+00
#
#        comment_MFT_usage_bin  jaccard_sim_split  jaccard_sim_same  \
# count           1.239691e+06       1.239691e+06      1.239691e+06
# mean            7.288945e-01       4.774898e-01      3.526817e-01
# std             4.445306e-01       1.834957e-01      2.234096e-01
# min             0.000000e+00       0.000000e+00      0.000000e+00
# 25%             0.000000e+00       3.750000e-01      2.000000e-01
# 50%             1.000000e+00       4.666667e-01      3.333333e-01
# 75%             1.000000e+00       5.714286e-01      5.000000e-01
# max             1.000000e+00       1.000000e+00      1.000000e+00
#
#           MFT_any_n   MFT_any_bin
# count  1.239691e+06  1.239691e+06
# mean   1.823669e+01  9.943559e-01
# std    1.573771e+01  7.491526e-02
# min    0.000000e+00  0.000000e+00
# 25%    8.000000e+00  1.000000e+00
# 50%    1.400000e+01  1.000000e+00
# 75%    2.300000e+01  1.000000e+00
# max    4.110000e+02  1.000000e+00
#
# [8 rows x 54 columns]

# %%
print(data['delta_thread'].value_counts())
print(data['delta'].value_counts())
# Out:
# 0    755551
# 1    484140
# Name: delta_thread, dtype: int64
# 0    1229340
# 1      10351
# Name: delta, dtype: int64

# %% [markdown]
# HYPOTHESIS 1 TESTS: Are arguments which use moral language (as detected using either paradigm) more persuasive than those that do not?

# %%
print('FULL DATA ANALYSES:')
for d in MFT_domains_all:
    print('MFT DOMAIN: ' + d)    
    print('ASSOCIATION WITH DELTA THREAD DATA (DELTA_THREAD):')
    # print(pd.crosstab(data.delta_thread, data[d]).apply(lambda r: r/r.sum(), axis=1))
    try:
        logit = smf.glm(formula = 'delta_thread ~ data[d]',
                        data = data,
                        family = sm.families.Binomial()).fit()
        print(logit.summary())
        print('\n', 'Coef. odds ratio:', '\n', np.exp(logit.params))
        outcomes.append(['H1', 'full data', 'delta_thread', d, logit.params[1], logit.params[1] > 0, logit.pvalues[1] < 0.05])
        print('\n', '\n')
    except:
        outcomes.append(['H1', 'full data', 'delta_thread', d, 'error', 'error', 'error'])
        pass
    
    
    print('ASSOCIATION WITH DELTA POST DATA (DELTA):')    
    # print(pd.crosstab(data.delta, data[d]).apply(lambda r: r/r.sum(), axis=1))
    try:
        logit = smf.glm(formula = 'delta_thread ~ data[d]',
                        data = data,
                        family = sm.families.Binomial()).fit()
        print(logit.summary())
        print('\n', 'Coef. odds ratio:', '\n', np.exp(logit.params))
        outcomes.append(['H1', 'full data', 'delta', d, logit.params[1], logit.params[1] > 0, logit.pvalues[1] < 0.05])
        print('', '-' * 80, '\n', '-' * 80, '\n', '-' * 80, '\n', '-' * 80)
        print('\n', '\n', '\n', '\n')
    except:
        outcomes.append(['H1', 'full data', 'delta', d, 'error', 'error', 'error'])
        pass
    
    
print('DATA SUBSET ANALYSES (DELTA-AWARDED SUBSET):')
for d in MFT_domains_all:
    # There are no delta_thread models here because the delta-awarded subset is perfectly collinear
    print('MFT DOMAIN: ' + d)    
    print('ASSOCIATION WITH DELTA POST DATA (DELTA):')    
    # print(pd.crosstab(data_subset_deltas.delta, data_subset_deltas[d]).apply(lambda r: r/r.sum(), axis=1))
    try:
        logit = smf.glm(formula = 'delta ~ data_subset_deltas[d]',
                        data = data_subset_deltas,
                        family = sm.families.Binomial()).fit()
        print(logit.summary())
        print('\n', 'Coef. odds ratio:', '\n', np.exp(logit.params))
        outcomes.append(['H1', 'delta subset', 'delta', d, logit.params[1], logit.params[1] > 0, logit.pvalues[1] < 0.05])
        print('', '-' * 80, '\n', '-' * 80, '\n', '-' * 80, '\n', '-' * 80)
        print('\n', '\n', '\n', '\n')
    except:
        outcomes.append(['H1', 'delta subset', 'delta', d, 'error', 'error', 'error'])
        pass
# Out:
# FULL DATA ANALYSES:
# MFT DOMAIN: comment_MFT_usage_bin
# ASSOCIATION WITH DELTA THREAD DATA (DELTA_THREAD):
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:           delta_thread   No. Observations:              1239691
# Model:                            GLM   Df Residuals:                  1239689
# Model Family:                Binomial   Df Model:                            1
# Link Function:                  logit   Scale:                             1.0
# Method:                          IRLS   Log-Likelihood:            -8.2924e+05
# Date:                Fri, 08 Sep 2017   Deviance:                   1.6585e+06
# Time:                        03:20:49   Pearson chi2:                 1.24e+06
# No. Iterations:                     4
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.4025      0.004   -114.347      0.000      -0.409      -0.396
# data[d]       -0.0585      0.004    -14.167      0.000      -0.067      -0.050
# ==============================================================================
#
#  Coef. odds ratio:
#  Intercept    0.668646
# data[d]      0.943172
# dtype: float64
#
#
#
# ASSOCIATION WITH DELTA POST DATA (DELTA):
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:           delta_thread   No. Observations:              1239691
# Model:                            GLM   Df Residuals:                  1239689
# Model Family:                Binomial   Df Model:                            1
# Link Function:                  logit   Scale:                             1.0
# Method:                          IRLS   Log-Likelihood:            -8.
# =========================================================================================
#
#  Coef. odds ratio:
#  Intercept                0.022025
# data_subset_deltas[d]    0.967391
# dtype: float64
#  --------------------------------------------------------------------------------
#  --------------------------------------------------------------------------------
#  --------------------------------------------------------------------------------
#  --------------------------------------------------------------------------------
#
#
#
#
#
# MFT DOMAIN: comment_authority_virtue
# ASSOCIATION WITH DELTA POST DATA (DELTA):
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                  delta   No. Observations:               484140
# Model:                            GLM   Df Residuals:                   484138
# Model Family:                Binomial   Df Model:                            1
# Link Function:                  logit   Scale:                             1.0
# Method:                          IRLS   Log-Likelihood:                -49359.
# Date:                Fri, 08 Sep 2017   Deviance:                       98717.
# Time:                        03:23:33   Pearson chi2:                 4.73e+05
# No. Iterations:                     7
# =========================================================================================
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                -3.9483      0.011   -366.808      0.000      -3.969      -3.927
# data_subset_deltas[d]     0.1695      0.004     42.034      0.000       0.162       0.177
# =========================================================================================
#
#  Coef. odds ratio:
#  Intercept                0.019288
# data_subset_deltas[d]    1.184724
# dtype: float64
#  --------------------------------------------------------------------------------
#  --------------------------------------------------------------------------------
#  --------------------------------------------------------------------------------
#  --------------------------------------------------------------------------------
#
#
#
#
#
# MFT DOMAIN: comment_authority_vice
# ASSOCIATION WITH DELTA POST DATA (DELTA):
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                  delta   No. Observations:               484140
# Model:                            GLM   Df Residuals:                   484138
# Model Family:                Binomial   Df Model:                            1
# Link Function:                  logit   Scale:                             1.0
# Method:                          IRLS   Log-Likelihood:                -49921.
# Date:                Fri, 08 Sep 2017   Deviance:                       99842.
# Time:                        03:23:34   Pearson chi2:                 4.82e+05
# No. Iterations:                     7
# =========================================================================================
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                -3.8488      0.010   -380.074      0.000      -3.869      -3.829
# data_subset_deltas[d]     0.2650      0.015     17.282      0.000       0.235       0.295
# =========================================================================================
#
#  Coef. odds ratio:
#  Intercept                0.021306
# data_subset_deltas[d]    1.303437
# dtype: float64
#  --------------------------------------------------------------------------------
#  --------------------------------------------------------------------------------
#  --------------------------------------------------------------------------------
#  --------------------------------------------------------------------------------
#
#
#
#
#
# MFT DOMAIN: op_purity_virtue
# ASSOCIATION WITH DELTA POST DATA (DELTA):
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                  delta   No. Observations:               484140
# Model:                            GLM   Df Residuals:                   484138
# Model Family:                Binomial   Df Model:                            1
# Link Function:                  logit   Scale:                             1.0
# Method:                          IRLS   Log-Likelihood:                -50042.
# Date:                Fri, 08 Sep 2017   Deviance:                   1.0008e+05
# Time:                        03:23:35   Pearson chi2:                 4.84e+05
# No. Iterations:                     7
# =========================================================================================
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                -3.8206      0.010   -368.013      0.000      -3.841      -3.800
# data_subset_deltas[d]    -0.0155      0.016     -0.998      0.318      -0.046       0.015
# =========================================================================================
#
#  Coef. odds ratio:
#  Intercept                0.021914
# data_subset_deltas[d]    0.984619
# dtype: float64
#  --------------------------------------------------------------------------------
#  --------------------------------------------------------------------------------
#  --------------------------------------------------------------------------------
#  --------------------------------------------------------------------------------
#
#
#
#
#
# MFT DOMAIN: op_purity_vice
# ASSOCIATION WITH DELTA POST DATA (DELTA):
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                  delta   No. Observations:               484140
# Model:                            GLM   Df Residuals:                   484138
# Model Family:                Binomial   Df Model:                            1
# Link Function:                  logit   Scale:                             1.0
# Method:                          IRLS   Log-Likelihood:                -50042.
# Date:                Fri, 08 Sep 2017   Deviance:                   1.0008e+05
# Time:                        03:23:36   Pearson chi2:                 4.84e+05
# No. Iterations:                     7
# =========================================================================================
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                -3.8176      0.012   -317.651      0.000      -3.841      -3.794
# data_subset_deltas[d]    -0.0051      0.006     -0.898      0.369      -0.016       0.006
# =========================================================================================
#
#  Coef. odds ratio:
#  Intercept                0.021981
# data_subset_deltas[d]    0.994913
# dtype: float64
#  --------------------------------------------------------------------------------
#  --------------------------------------------------------------------------------
#  --------------------------------------------------------------------------------
#  --------------------------------------------------------------------------------
#
#
#
#
#
# MFT DOMAIN: comment_purity_virtue
# ASSOCIATION WITH DELTA POST DATA (DELTA):
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                  delta   No. Observations:               484140
# Model:                            GLM   Df Residuals:                   484138
# Model Family:                Binomial   Df Model:                            1
# Link Function:                  logit   Scale:                             1.0
# Method:                          IRLS   Log-Likelihood:                -49854.
# Date:                Fri, 08 Sep 2017   Deviance:                       99708.
# Time:                        03:23:36   Pearson chi2:                 4.81e+05
# No. Iterations:                     7
# =========================================================================================
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                -3.8546      0.010   -380.269      0.000      -3.874      -3.835
# data_subset_deltas[d]     0.3687      0.016     22.447      0.000       0.337       0.401
# =========================================================================================
#
#  Coef. odds ratio:
#  Intercept                0.021182
# data_subset_deltas[d]    1.445846
# dtype: float64
#  --------------------------------------------------------------------------------
#  --------------------------------------------------------------------------------
#  --------------------------------------------------------------------------------
#  --------------------------------------------------------------------------------
#
#
#
#
#
# MFT DOMAIN: comment_purity_vice
# ASSOCIATION WITH DELTA POST DATA (DELTA):
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                  delta   No. Observations:               484140
# Model:                            GLM   Df Residuals:                   484138
# Model Family:                Binomial   Df Model:                            1
# Link Function:                  logit   Scale:                             1.0
# Method:                          IRLS   Log-Likelihood:                -49169.
# Date:                Fri, 08 Sep 2017   Deviance:                       98338.
# Time:                        03:23:37   Pearson chi2:                 4.72e+05
# No. Iterations:                     7
# =========================================================================================
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                -3.9689      0.011   -364.994      0.000      -3.990      -3.948
# data_subset_deltas[d]     0.2876      0.006     46.440      0.000       0.276       0.300
# =========================================================================================
#
#  Coef. odds ratio:
#  Intercept                0.018894
# data_subset_deltas[d]    1.333279
# dtype: float64
#  --------------------------------------------------------------------------------
#  --------------------------------------------------------------------------------
#  --------------------------------------------------------------------------------
#  --------------------------------------------------------------------------------
#
#
#
#
#
# MFT DOMAIN: MFT_any_bin
# ASSOCIATION WITH DELTA POST DATA (DELTA):
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                  delta   No. Observations:               484140
# Model:                            GLM   Df Residuals:                   484138
# Model Family:                Binomial   Df Model:                            1
# Link Function:                  logit   Scale:                             1.0
# Method:                          IRLS   Log-Likelihood:                -50034.
# Date:                Fri, 08 Sep 2017   Deviance:                   1.0007e+05
# Time:                        03:23:38   Pearson chi2:                 4.84e+05
# No. Iterations:                     7
# =========================================================================================
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                -4.4920      0.184    -24.467      0.000      -4.852      -4.132
# data_subset_deltas[d]     0.6711      0.184      3.650      0.000       0.311       1.031
# =========================================================================================
#
#  Coef. odds ratio:
#  Intercept                0.011198
# data_subset_deltas[d]    1.956370
# dtype: float64
#  --------------------------------------------------------------------------------
#  --------------------------------------------------------------------------------
#  --------------------------------------------------------------------------------
#  --------------------------------------------------------------------------------
#
#
#
#
#
# MFT DOMAIN: MFT_any_n
# ASSOCIATION WITH DELTA POST DATA (DELTA):
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                  delta   No. Observations:               484140
# Model:                            GLM   Df Residuals:                   484138
# Model Family:                Binomial   Df Model:                            1
# Link Function:                  logit   Scale:                             1.0
# Method:                          IRLS   Log-Likelihood:                -48971.
# Date:                Fri, 08 Sep 2017   Deviance:                       97943.
# Time:                        03:23:39   Pearson chi2:                 4.73e+05
# No. Iterations:                     7
# =========================================================================================
#                             coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Intercept                -4.2864      0.014   -296.786      0.000      -4.315      -4.258
# data_subset_deltas[d]     0.0216      0.000     52.574      0.000       0.021       0.022
# =========================================================================================
#
#  Coef. odds ratio:
#  Intercept                0.013754
# data_subset_deltas[d]    1.021789
# dtype: float64
#  --------------------------------------------------------------------------------
#  --------------------------------------------------------------------------------
#  --------------------------------------------------------------------------------
#  --------------------------------------------------------------------------------

# %% [markdown]
# HYPOTHESIS 2 TESTS: A positive relationship exists between the (Jaccard) similarity of OP and a responder in their MFT affinities and the persuasiveness of that responder.

# %%
print('FULL DATA ANALYSES:')
try:
    logit = smf.glm(formula = 'delta_thread ~ jaccard_sim_same',
                    data = data,
                    family = sm.families.Binomial()).fit()
    print(logit.summary())
    print('\n', 'Coef. odds ratio:', '\n', np.exp(logit.params))
    outcomes.append(['H2', 'full data', 'delta_thread', 'jaccard_sim_same', logit.params[1], logit.params[1] > 0, logit.pvalues[1] < 0.05])
    print('\n', '\n')
except:
    outcomes.append(['H2', 'full data', 'delta_thread', 'jaccard_sim_same', 'error', 'error', 'error'])
    pass

try:
    logit = smf.glm(formula = 'delta_thread ~ jaccard_sim_split',
                    data = data,
                    family = sm.families.Binomial()).fit()
    print(logit.summary())
    print('\n', 'Coef. odds ratio:', '\n', np.exp(logit.params))
    outcomes.append(['H2', 'full data', 'delta_thread', 'jaccard_sim_split', logit.params[1], logit.params[1] > 0, logit.pvalues[1] < 0.05])
    print('\n', '\n')
except:
    outcomes.append(['H2', 'full data', 'delta_thread', 'jaccard_sim_split', 'error', 'error', 'error'])
    pass

try:
    logit = smf.glm(formula = 'delta ~ jaccard_sim_same',
                    data = data,
                    family = sm.families.Binomial()).fit()
    print(logit.summary())
    print('\n', 'Coef. odds ratio:', '\n', np.exp(logit.params))
    outcomes.append(['H2', 'full data', 'delta', 'jaccard_sim_same', logit.params[1], logit.params[1] > 0, logit.pvalues[1] < 0.05])
    print('\n', '\n')
except:
    outcomes.append(['H2', 'full data', 'delta', 'jaccard_sim_same', 'error', 'error', 'error'])
    pass

try:
    logit = smf.glm(formula = 'delta ~ jaccard_sim_split',
                    data = data,
                    family = sm.families.Binomial()).fit()
    print(logit.summary())
    print('\n', 'Coef. odds ratio:', '\n', np.exp(logit.params))
    outcomes.append(['H2', 'full data', 'delta', 'jaccard_sim_split', logit.params[1], logit.params[1] > 0, logit.pvalues[1] < 0.05])
    print('', '-' * 80, '\n', '-' * 80, '\n', '-' * 80, '\n', '-' * 80)
    print('\n', '\n', '\n', '\n')
except:
    outcomes.append(['H2', 'full data', 'delta', 'jaccard_sim_split', 'error', 'error', 'error'])
    pass


print('DATA SUBSET ANALYSES (DELTA-AWARDED SUBSET):')
# Again, no delta_thread prediction models are here due to their collinearity
try:
    logit = smf.glm(formula = 'delta ~ jaccard_sim_same',
                    data = data_subset_deltas,
                    family = sm.families.Binomial()).fit()
    print(logit.summary())
    print('\n', 'Coef. odds ratio:', '\n', np.exp(logit.params))
    outcomes.append(['H2', 'delta subset', 'delta', 'jaccard_sim_same', logit.params[1], logit.params[1] > 0, logit.pvalues[1] < 0.05])
    print('\n', '\n')
except:
    outcomes.append(['H2', 'delta subset', 'delta', 'jaccard_sim_same', 'error', 'error', 'error'])
    pass

try:
    logit = smf.glm(formula = 'delta ~ jaccard_sim_split',
                    data = data_subset_deltas,
                    family = sm.families.Binomial()).fit()
    print(logit.summary())
    print('\n', 'Coef. odds ratio:', '\n', np.exp(logit.params))
    outcomes.append(['H2', 'delta subset', 'delta', 'jaccard_sim_split', logit.params[1], logit.params[1] > 0, logit.pvalues[1] < 0.05])
    print('', '-' * 80, '\n', '-' * 80, '\n', '-' * 80, '\n', '-' * 80)
    print('\n', '\n', '\n', '\n')
except:
    outcomes.append(['H2', 'delta subset', 'delta', 'jaccard_sim_split', 'error', 'error', 'error'])
    pass


print('DATA SUBSET ANALYSES (MORAL SUBSET):')
try:
    logit = smf.glm(formula = 'delta_thread ~ jaccard_sim_same',
                    data = data_subset_moral,
                    family = sm.families.Binomial()).fit()
    print(logit.summary())
    print('\n', 'Coef. odds ratio:', '\n', np.exp(logit.params))
    outcomes.append(['H2', 'moral subset', 'delta_thread', 'jaccard_sim_same', logit.params[1], logit.params[1] > 0, logit.pvalues[1] < 0.05])
    print('\n', '\n')
except:
    outcomes.append(['H2', 'moral subset', 'delta_thread', 'jaccard_sim_same', 'error', 'error', 'error'])
    pass

try:
    logit = smf.glm(formula = 'delta_thread ~ jaccard_sim_split',
                    data = data_subset_moral,
                    family = sm.families.Binomial()).fit()
    print(logit.summary())
    print('\n', 'Coef. odds ratio:', '\n', np.exp(logit.params))
    outcomes.append(['H2', 'moral subset', 'delta_thread', 'jaccard_sim_split', logit.params[1], logit.params[1] > 0, logit.pvalues[1] < 0.05])
    print('\n', '\n')
except:
    outcomes.append(['H2', 'moral subset', 'delta_thread', 'jaccard_sim_split', 'error', 'error', 'error'])
    pass

try:
    logit = smf.glm(formula = 'delta ~ jaccard_sim_same',
                    data = data_subset_moral,
                    family = sm.families.Binomial()).fit()
    print(logit.summary())
    print('\n', 'Coef. odds ratio:', '\n', np.exp(logit.params))
    outcomes.append(['H2', 'moral subset', 'delta', 'jaccard_sim_same', logit.params[1], logit.params[1] > 0, logit.pvalues[1] < 0.05])
    print('\n', '\n')
except:
    outcomes.append(['H2', 'moral subset', 'delta', 'jaccard_sim_same', 'error', 'error', 'error'])
    pass

try:
    logit = smf.glm(formula = 'delta ~ jaccard_sim_split',
                    data = data_subset_moral,
                    family = sm.families.Binomial()).fit()
    print(logit.summary())
    print('\n', 'Coef. odds ratio:', '\n', np.exp(logit.params))
    outcomes.append(['H2', 'moral subset', 'delta', 'jaccard_sim_split', logit.params[1], logit.params[1] > 0, logit.pvalues[1] < 0.05])
    print('', '-' * 80, '\n', '-' * 80, '\n', '-' * 80, '\n', '-' * 80)
    print('\n', '\n', '\n', '\n')
except:
    outcomes.append(['H2', 'moral subset', 'delta', 'jaccard_sim_split', 'error', 'error', 'error'])
    pass
# Out:
# FULL DATA ANALYSES:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:           delta_thread   No. Observations:              1239691
# Model:                            GLM   Df Residuals:                  1239689
# Model Family:                Binomial   Df Model:                            1
# Link Function:                  logit   Scale:                             1.0
# Method:                          IRLS   Log-Likelihood:            -8.2894e+05
# Date:                Fri, 08 Sep 2017   Deviance:                   1.6579e+06
# Time:                        03:23:41   Pearson chi2:                 1.24e+06
# No. Iterations:                     4
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept           -0.3631      0.003   -105.703      0.000      -0.370      -0.356
# jaccard_sim_same    -0.2333      0.008    -28.163      0.000      -0.250      -0.217
# ====================================================================================
#
#  Coef. odds ratio:
#  Intercept           0.695518
# jaccard_sim_same    0.791917
# dtype: float64
#
#
#
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:           delta_thread   No. Observations:              1239691
# Model:                            GLM   Df Residuals:                  1239689
# Model Family:                Binomial   Df Model:                            1
# Link Function:                  logit   Scale:                             1.0
# Method:                          IRLS   Log-Likelihood:            -8.2904e+05
# Date:                Fri, 08 Sep 2017   Deviance:                   1.6581e+06
# Time:                        03:23:42   Pearson chi2:                 1.24e+06
# No. Iterations:                     4
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept            -0.3283      0.005    -64.063      0.000      -0.338      -0.318
# jaccard_sim_split    -0.2450      0.010    -24.364      0.000      -0.265      -0.225
# =====================================================================================
#
#  Coef. odds ratio:
#  Intercept            0.720131
# jaccard_sim_split    0.782722
# dtype: float64
#
#
#
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                  delta   No. Observations:              1239691
# Model:                            GLM   Df Residuals:                  1239689
# Model Family:                Binomial   Df Model:                            1
# Link Function:                  logit   Scale:                             1.0
# Method:                          IRLS   Log-Likelihood:                -59150.
# Date:                Fri, 08 Sep 2017   Deviance:                   1.1830e+05
# Time:                        03:23:45   Pearson chi2:                 1.23e+06
# No. Iterations:                     8
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept           -5.3756      0.020   -270.390      0.000      -5.415      -5.337
# jaccard_sim_same     1.5224      0.040     38.515      0.000       1.445       1.600
# ====================================================================================
#
#  Coef. odds ratio:
#  Intercept           0.004628
# jaccard_sim_same    4.583144
# dtype: float64
#
#
#
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                  delta   No. Observations:              1239691
# Model:                            GLM   Df Residuals:                  1239689
# Model Family:                Binomial   Df Model:                            1
# Link Function:                  logit   Scale:                             1.0
# Method:                          IRLS   Log-Likelihood:                -59594.
# Date:                Fri, 08 Sep 2017   Deviance:                   1.1919e+05
# Time:                        03:23:48   Pearson chi2:                 1.24e+06
# No. Iterations:                     8
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept            -5.3621      0.029   -186.360      0.000      -5.418      -5.306
# jaccard_sim_split     1.1760      0.052     22.525      0.000       1.074       1.278
# =====================================================================================
#
#  Coef. odds ratio:
#  Intercept            0.004691
# jaccard_sim_split    3.241542
# dtype: float64
#  --------------------------------------------------------------------------------
#  --------------------------------------------------------------------------------
#  --------------------------------------------------------------------------------
#  --------------------------------------------------------------------------------
#
#
#
#
#
# DATA SUBSET ANALYSES (DELTA-AWARDED SUBSET):
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                  delta   No. Observations:               484140
# Model:                            GLM   Df Residuals:                   484138
# Model Family:                Binomial   Df Model:                            1
# Link Function:                  logit   Scale:                             1.0
# Method:                          IRLS   Log-Likelihood:                -49224.
# Date:                Fri, 08 Sep 2017   Deviance:                       98448.
# Time:                        03:23:52   Pearson chi2:                 4.78e+05
# No. Iterations:                     7
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept           -4.4670      0.020   -224.927      0.000      -4.506      -4.428
# jaccard_sim_same     1.6557      0.040     41.875      0.000       1.578       1.733
# ====================================================================================
#
#  Coef. odds ratio:
#  Intercept           0.011482
# jaccard_sim_same    5.236846
# dtype: float64
#
#
#
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                  delta   No. Observations:               484140
# Model:                            GLM   Df Residuals:                   484138
# Model Family:                Binomial   Df Model:                            1
# Link Function:                  logit   Scale:                             1.0
# Method:                          IRLS   Log-Likelihood:                -49724.
# Date:                Fri, 08 Sep 2017   Deviance:                       99449.
# Time:                        03:23:53   Pearson chi2:                 4.82e+05
# No. Iterations:                     7
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept            -4.4828      0.029   -155.514      0.000      -4.539      -4.426
# jaccard_sim_split     1.3331      0.052     25.466      0.000       1.230       1.436
# =====================================================================================
#
#  Coef. odds ratio:
#  Intercept            0.011302
# jaccard_sim_split    3.792601
# dtype: float64
#  --------------------------------------------------------------------------------
#  --------------------------------------------------------------------------------
#  --------------------------------------------------------------------------------
#  --------------------------------------------------------------------------------
#
#
#
#
#
# DATA SUBSET ANALYSES (MORAL SUBSET):
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:           delta_thread   No. Observations:              1232694
# Model:                            GLM   Df Residuals:                  1232692
# Model Family:                Binomial   Df Model:                            1
# Link Function:                  logit   Scale:                             1.0
# Method:                          IRLS   Log-Likelihood:            -8.2424e+05
# Date:                Fri, 08 Sep 2017   Deviance:                   1.6485e+06
# Time:                        03:23:55   Pearson chi2:                 1.23e+06
# No. Iterations:                     4
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept           -0.3592      0.003   -103.657      0.000      -0.366      -0.352
# jaccard_sim_same    -0.2465      0.008    -29.142      0.000      -0.263      -0.230
# ====================================================================================
#
#  Coef. odds ratio:
#  Intercept           0.698231
# jaccard_sim_same    0.781530
# dtype: float64
#
#
#
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:           delta_thread   No. Observations:              1232694
# Model:                            GLM   Df Residuals:                  1232692
# Model Family:                Binomial   Df Model:                            1
# Link Function:                  logit   Scale:                             1.0
# Method:                          IRLS   Log-Likelihood:            -8.2435e+05
# Date:                Fri, 08 Sep 2017   Deviance:                   1.6487e+06
# Time:                        03:23:57   Pearson chi2:                 1.23e+06
# No. Iterations:                     4
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept            -0.3228      0.005    -62.164      0.000      -0.333      -0.313
# jaccard_sim_split    -0.2578      0.010    -25.117      0.000      -0.278      -0.238
# =====================================================================================
#
#  Coef. odds ratio:
#  Intercept            0.724093
# jaccard_sim_split    0.772731
# dtype: float64
#
#
#
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                  delta   No. Observations:              1232694
# Model:                            GLM   Df Residuals:                  1232692
# Model Family:                Binomial   Df Model:                            1
# Link Function:                  logit   Scale:                             1.0
# Method:                          IRLS   Log-Likelihood:                -58893.
# Date:                Fri, 08 Sep 2017   Deviance:                   1.1779e+05
# Time:                        03:23:59   Pearson chi2:                 1.22e+06
# No. Iterations:                     8
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept           -5.4045      0.020   -268.365      0.000      -5.444      -5.365
# jaccard_sim_same     1.6131      0.040     39.999      0.000       1.534       1.692
# ====================================================================================
#
#  Coef. odds ratio:
#  Intercept           0.004496
# jaccard_sim_same    5.018227
# dtype: float64
#
#
#
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                  delta   No. Observations:              1232694
# Model:                            GLM   Df Residuals:                  1232692
# Model Family:                Binomial   Df Model:                            1
# Link Function:                  logit   Scale:                             1.0
# Method:                          IRLS   Log-Likelihood:                -59364.
# Date:                Fri, 08 Sep 2017   Deviance:                   1.1873e+05
# Time:                        03:24:02   Pearson chi2:                 1.23e+06
# No. Iterations:                     8
# =====================================================================================
#                         coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept            -5.4029      0.029   -184.134      0.000      -5.460      -5.345
# jaccard_sim_split     1.2688      0.054     23.712      0.000       1.164       1.374
# =====================================================================================
#
#  Coef. odds ratio:
#  Intercept            0.004504
# jaccard_sim_split    3.556592
# dtype: float64
#  --------------------------------------------------------------------------------
#  --------------------------------------------------------------------------------
#  --------------------------------------------------------------------------------
#  --------------------------------------------------------------------------------

# %% [markdown]
# HYPOTHESIS 3 TESTS: Other things being equal, a moralistic argument will be more likely to result in a delta if the argument is presented quickly after the initial post.

# %%
print('FULL DATA ANALYSES:')
try:
    logit = smf.glm(formula = 'delta_thread ~ time_diff',
                    data = data,
                    family = sm.families.Binomial()).fit()
    print(logit.summary())
    print('\n', 'Coef. odds ratio:', '\n', np.exp(logit.params))
    outcomes.append(['H3', 'full data', 'delta_thread', 'time_diff', logit.params[1], logit.params[1] > 0, logit.pvalues[1] < 0.05])
    print('\n', '\n')
except:
    outcomes.append(['H3', 'full data', 'delta_thread', 'time_diff', 'error', 'error', 'error'])
    pass

try:
    logit = smf.glm(formula = 'delta ~ time_diff',
                    data = data,
                    family = sm.families.Binomial()).fit()
    print(logit.summary())
    print('\n', 'Coef. odds ratio:', '\n', np.exp(logit.params))
    outcomes.append(['H3', 'full data', 'delta', 'time_diff', logit.params[1], logit.params[1] > 0, logit.pvalues[1] < 0.05])
    print('', '-' * 80, '\n', '-' * 80, '\n', '-' * 80, '\n', '-' * 80)
    print('\n', '\n', '\n', '\n')
except:
    outcomes.append(['H3', 'full data', 'delta', 'time_diff', 'error', 'error', 'error'])
    pass


print('DATA SUBSET ANALYSES (DELTA-AWARDED SUBSET):')
# Again, no delta_thread prediction models are here due to their collinearity
try:
    logit = smf.glm(formula = 'delta ~ time_diff',
                    data = data_subset_deltas,
                    family = sm.families.Binomial()).fit()
    print(logit.summary())
    print('\n', 'Coef. odds ratio:', '\n', np.exp(logit.params))
    outcomes.append(['H3', 'delta subset', 'delta', 'time_diff', logit.params[1], logit.params[1] > 0, logit.pvalues[1] < 0.05])
    print('', '-' * 80, '\n', '-' * 80, '\n', '-' * 80, '\n', '-' * 80)
    print('\n', '\n', '\n', '\n')
except:
    outcomes.append(['H3', 'delta subset', 'delta', 'time_diff', 'error', 'error', 'error'])
    pass


print('DATA SUBSET ANALYSES (MORAL SUBSET):')
try:
    logit = smf.glm(formula = 'delta_thread ~ time_diff',
                    data = data_subset_moral,
                    family = sm.families.Binomial()).fit()
    print(logit.summary())
    print('\n', 'Coef. odds ratio:', '\n', np.exp(logit.params))
    outcomes.append(['H3', 'moral subset', 'delta_thread', 'time_diff', logit.params[1], logit.params[1] > 0, logit.pvalues[1] < 0.05])
    print('\n', '\n')
except:
    outcomes.append(['H3', 'moral subset', 'delta_thread', 'time_diff', 'error', 'error', 'error'])
    pass

try:
    logit = smf.glm(formula = 'delta ~ time_diff',
                    data = data_subset_moral,
                    family = sm.families.Binomial()).fit()
    print(logit.summary())
    print('\n', 'Coef. odds ratio:', '\n', np.exp(logit.params))
    outcomes.append(['H3', 'moral subset', 'delta', 'time_diff', logit.params[1], logit.params[1] > 0, logit.pvalues[1] < 0.05])
    print('', '-' * 80, '\n', '-' * 80, '\n', '-' * 80, '\n', '-' * 80)
    print('\n', '\n', '\n', '\n')
except:
    outcomes.append(['H3', 'moral subset', 'delta', 'time_diff', 'error', 'error', 'error'])
    pass
# Out:
# FULL DATA ANALYSES:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:           delta_thread   No. Observations:              1239691
# Model:                            GLM   Df Residuals:                  1239689
# Model Family:                Binomial   Df Model:                            1
# Link Function:                  logit   Scale:                             1.0
# Method:                          IRLS   Log-Likelihood:            -8.2928e+05
# Date:                Fri, 08 Sep 2017   Deviance:                   1.6586e+06
# Time:                        03:24:04   Pearson chi2:                 1.24e+06
# No. Iterations:                     4
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.4479      0.002   -240.766      0.000      -0.452      -0.444
# time_diff   3.557e-08   3.36e-09     10.597      0.000     2.9e-08    4.21e-08
# ==============================================================================
#
#  Coef. odds ratio:
#  Intercept    0.638981
# time_diff    1.000000
# dtype: float64
#
#
#
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                  delta   No. Observations:              1239691
# Model:                            GLM   Df Residuals:                  1239689
# Model Family:                Binomial   Df Model:                            1
# Link Function:                  logit   Scale:                             1.0
# Method:                          IRLS   Log-Likelihood:                -58537.
# Date:                Fri, 08 Sep 2017   Deviance:                   1.1707e+05
# Time:                        03:24:07   Pearson chi2:                 1.80e+16
# No. Iterations:                    11
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -4.2865      0.014   -316.079      0.000      -4.313      -4.260
# time_diff  -1.647e-05   4.19e-07    -39.258      0.000   -1.73e-05   -1.56e-05
# ==============================================================================
#
#  Coef. odds ratio:
#  Intercept    0.013753
# time_diff    0.999984
# dtype: float64
#  --------------------------------------------------------------------------------
#  --------------------------------------------------------------------------------
#  --------------------------------------------------------------------------------
#  --------------------------------------------------------------------------------
#
#
#
#
#
# DATA SUBSET ANALYSES (DELTA-AWARDED SUBSET):
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                  delta   No. Observations:               484140
# Model:                            GLM   Df Residuals:                   484138
# Model Family:                Binomial   Df Model:                            1
# Link Function:                  logit   Scale:                             1.0
# Method:                          IRLS   Log-Likelihood:                -48463.
# Date:                Fri, 08 Sep 2017   Deviance:                       96926.
# Time:                        03:24:10   Pearson chi2:                 1.94e+16
# No. Iterations:                    11
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -3.2359      0.014   -228.476      0.000      -3.264      -3.208
# time_diff  -1.958e-05   4.52e-07    -43.306      0.000   -2.05e-05   -1.87e-05
# ==============================================================================
#
#  Coef. odds ratio:
#  Intercept    0.039324
# time_diff    0.999980
# dtype: float64
#  --------------------------------------------------------------------------------
#  --------------------------------------------------------------------------------
#  --------------------------------------------------------------------------------
#  --------------------------------------------------------------------------------
#
#
#
#
#
# DATA SUBSET ANALYSES (MORAL SUBSET):
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:           delta_thread   No. Observations:              1232694
# Model:                            GLM   Df Residuals:                  1232692
# Model Family:                Binomial   Df Model:                            1
# Link Function:                  logit   Scale:                             1.0
# Method:                          IRLS   Log-Likelihood:            -8.2461e+05
# Date:                Fri, 08 Sep 2017   Deviance:                   1.6492e+06
# Time:                        03:24:12   Pearson chi2:                 1.23e+06
# No. Iterations:                     4
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.4477      0.002   -240.018      0.000      -0.451      -0.444
# time_diff   3.485e-08   3.37e-09     10.358      0.000    2.83e-08    4.14e-08
# ==============================================================================
#
#  Coef. odds ratio:
#  Intercept    0.639069
# time_diff    1.000000
# dtype: float64
#
#
#
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                  delta   No. Observations:              1232694
# Model:                            GLM   Df Residuals:                  1232692
# Model Family:                Binomial   Df Model:                            1
# Link Function:                  logit   Scale:                             1.0
# Method:                          IRLS   Log-Likelihood:                -58342.
# Date:                Fri, 08 Sep 2017   Deviance:                   1.1668e+05
# Time:                        03:24:16   Pearson chi2:                 1.80e+16
# No. Iterations:                    11
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -4.2841      0.014   -315.373      0.000      -4.311      -4.257
# time_diff  -1.645e-05    4.2e-07    -39.173      0.000   -1.73e-05   -1.56e-05
# ==============================================================================
#
#  Coef. odds ratio:
#  Intercept    0.013786
# time_diff    0.999984
# dtype: float64
#  --------------------------------------------------------------------------------
#  --------------------------------------------------------------------------------
#  --------------------------------------------------------------------------------
#  --------------------------------------------------------------------------------

# %% [markdown]
# END: Export outcome list as .csv file

# %%
outcomes_df = pd.DataFrame(outcomes)
outcomes_df.to_csv("data_analysis_outcomes.csv")
